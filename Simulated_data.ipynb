# %%
import pandas as pd

# Simulated data
data = {
    'bank': ['CBE']*400 + ['BOA']*400 + ['Dashen']*400,
    'sentiment_label': ['Positive']*240 + ['Negative']*100 + ['Neutral']*60 +
                       ['Positive']*120 + ['Negative']*200 + ['Neutral']*80 +
                       ['Positive']*200 + ['Negative']*120 + ['Neutral']*80,
    'rating': [5]*160 + [4]*80 + [3]*60 + [2]*60 + [1]*40 +  # CBE
              [5]*80 + [4]*40 + [3]*80 + [2]*100 + [1]*100 +  # BOA
              [5]*120 + [4]*80 + [3]*80 + [2]*80 + [1]*40,    # Dashen
    'theme': ['UI']*100 + ['Reliability']*100 + ['Transaction Speed']*100 + ['Support']*100 +  # CBE
             ['Login Issues']*120 + ['Crashes']*100 + ['Slow Transfers']*100 + ['Feature Requests']*80 +  # BOA
             ['UI']*100 + ['Transaction Speed']*100 + ['Login Issues']*100 + ['Support']*100  # Dashen
}
df = pd.DataFrame(data)
df.to_csv('simulated_reviews.csv', index=False)
