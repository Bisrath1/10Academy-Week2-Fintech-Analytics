# %%
# insights.py
with open('task_4/insights.txt', 'w') as f:
    f.write("CBE Drivers: Fast UI, Reliability\n")
    f.write("CBE Pain Points: Slow Transfers, Bugs\n")
    f.write("BOA Drivers: Easy Transfers, Feature Availability\n")
    f.write("BOA Pain Points: Crashes, Login Errors\n")
    f.write("Dashen Drivers: Intuitive UI, Transaction Speed\n")
    f.write("Dashen Pain Points: Login Issues, Delays\n")

# %%
# Append to insights.py
with open('task_4/insights.txt', 'a') as f:
    f.write("Comparisons: CBE > Dashen > BOA in ratings/sentiment. Common issue: slow transfers.\n")

# %%
# Append to insights.py
with open('task_4/insights.txt', 'a') as f:
    f.write("Recommendations:\n")
    f.write("- CBE: Optimize transfer speeds (server upgrades), fix bugs (QA), add budgeting tools.\n")
    f.write("- BOA: Fix crashes (stress tests), improve login (fingerprint/OTP), add AI chatbot.\n")
    f.write("- Dashen: Streamline login (OTP fixes), optimize performance, add fingerprint login and budgeting tools.\n")
